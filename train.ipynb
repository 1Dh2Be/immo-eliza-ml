# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load csv file
data = pd.read_csv("data/properties_ml.csv")

data.dropna(subset="primary_energy_consumption_sqm", inplace=True)

# %%
from sklearn.model_selection import train_test_split

X = data.drop(["price", "Unnamed: 0"], axis=1)
y = data["price"]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
train_data = X_train.join(y_train)

# %%
pd.set_option('display.max_columns', None)

# %%
train_data.corr()
# Out:
#                                        property_type  zip_code  \
# property_type                               1.000000  0.087967
# zip_code                                    0.087967  1.000000
# total_area_sqm                              0.137544 -0.001976
# nbr_bedrooms                                0.431451  0.000549
# fl_terrace                                 -0.217590 -0.127446
# fl_garden                                   0.301024 -0.077550
# primary_energy_consumption_sqm              0.007671  0.004020
# subproperty_type_APARTMENT                 -0.817388 -0.022677
# subproperty_type_APARTMENT_BLOCK            0.160554 -0.053415
# subproperty_type_BUNGALOW                   0.061156  0.006208
# subproperty_type_CASTLE                     0.024975 -0.000866
# subproperty_type_CHALET                     0.030718  0.003716
# subproperty_type_COUNTRY_COTTAGE            0.050154  0.006293
# subproperty_type_DUPLEX                    -0.146900 -0.042988
# subproperty_type_EXCEPTIONAL_PROPERTY       0.085769 -0.020634
# subproperty_type_FARMHOUSE                  0.051804  0.008143
# subproperty_type_FLAT_STUDIO               -0.128923 -0.052040
# subproperty_type_GROUND_FLOOR              -0.177306 -0.051952
# subproperty_type_HOUSE                      0.773368  0.121721
# subproperty_type_KOT                       -0.065127 -0.046055
# subproperty_type_LOFT                      -0.063559 -0.020087
# subproperty_type_MANOR_HOUSE                0.042756  0.021519
# subproperty_type_MANSION                    0.074204 -0.018499
# subproperty_type_MIXED_USE_BUILDING         0.139710 -0.016907
# subproperty_type_OTHER_PROPERTY             0.032407  0.001315
# subproperty_type_PENTHOUSE                 -0.153716 -0.051579
# subproperty_type_SERVICE_FLAT              -0.080987  0.008878
# subproperty_type_TOWN_HOUSE                 0.075540 -0.027222
# subproperty_type_TRIPLEX                   -0.041187 -0.033938
# subproperty_type_VILLA                      0.204527 -0.006355
# province_Antwerp                           -0.040805 -0.378590
# province_Brussels                          -0.192100 -0.463625
# province_East Flanders                      0.073121  0.560619
# province_Flemish Brabant                    0.049353 -0.290345
# province_Hainaut                            0.130132  0.228631
# province_Limburg                            0.018164 -0.104892
# province_Liège                              0.052253 -0.082703
# province_Luxembourg                         0.044436  0.094734
# province_Namur                              0.037099  0.006983
# province_Walloon Brabant                    0.025789 -0.257655
# province_West Flanders                     -0.128601  0.471449
# state_building_AS_NEW                      -0.141191 -0.103250
# state_building_GOOD                         0.052257  0.091198
# state_building_JUST_RENOVATED               0.004356 -0.034232
# state_building_MISSING                     -0.093793  0.041130
# state_building_TO_BE_DONE_UP                0.103865 -0.035334
# state_building_TO_RENOVATE                  0.192529 -0.024081
# state_building_TO_RESTORE                   0.045558  0.006258
# price                                       0.113362 -0.035565
#
#                                        total_area_sqm  nbr_bedrooms  \
# property_type                                0.137544      0.431451
# zip_code                                    -0.001976      0.000549
# total_area_sqm                               1.000000      0.200330
# nbr_bedrooms                                 0.200330      1.000000
# fl_terrace                                  -0.022017     -0.024772
# fl_garden                                    0.033824      0.155898
# primary_energy_consumption_sqm               0.000709      0.003776
# subproperty_type_APARTMENT                  -0.112800     -0.337078
# subproperty_type_APARTMENT_BLOCK             0.063752      0.193912
# subproperty_type_BUNGALOW                   -0.003866     -0.007517
# subproperty_type_CASTLE                      0.074969      0.134121
# subproperty_type_CHALET                     -0.004720     -0.008503
# subproperty_type_COUNTRY_COTTAGE             0.034456      0.030511
# subproperty_type_DUPLEX                     -0.012412     -0.023663
# subproperty_type_EXCEPTIONAL_PROPERTY        0.052646      0.116467
# subproperty_type_FARMHOUSE                   0.022845      0.038097
# subproperty_type_FLAT_STUDIO                -0.034393     -0.169394
# subproperty_type_GROUND_FLOOR               -0.025817     -0.080430
# subproperty_type_HOUSE                       0.050705      0.241715
# subproperty_type_KOT                        -0.019369     -0.069516
# subproperty_type_LOFT                        0.001617     -0.022471
# subproperty_type_MANOR_HOUSE                 0.018139      0.040521
# subproperty_type_MANSION                     0.031276      0.094019
# subproperty_type_MIXED_USE_BUILDING          0.065898      0.056030
# subproperty_type_OTHER_PROPERTY              0.009118      0.015044
# subproperty_type_PENTHOUSE                  -0.009929     -0.028624
# subproperty_type_SERVICE_FLAT               -0.016643     -0.069278
# subproperty_type_TOWN_HOUSE                  0.002595      0.016296
# subproperty_type_TRIPLEX                    -0.000697      0.005563
# subproperty_type_VILLA                       0.053979      0.146576
# province_Antwerp                            -0.006767     -0.022367
# province_Brussels                           -0.010007     -0.041608
# province_East Flanders                       0.000737      0.011790
# province_Flemish Brabant                     0.001857      0.011874
# province_Hainaut                             0.028225      0.028471
# province_Limburg                             0.000866     -0.002241
# province_Liège                               0.002007      0.032597
# province_Luxembourg                          0.006905      0.048944
# province_Namur                               0.011861      0.032868
# province_Walloon Brabant                     0.009015      0.030550
# province_West Flanders                      -0.028653     -0.070835
# state_building_AS_NEW                       -0.000409     -0.040323
# state_building_GOOD                          0.002901      0.028098
# state_building_JUST_RENOVATED               -0.003380      0.006851
# state_building_MISSING                      -0.024777     -0.063207
# state_building_TO_BE_DONE_UP                 0.006932      0.046885
# state_building_TO_RENOVATE                   0.034981      0.076548
# state_building_TO_RESTORE                    0.011246      0.026970
# price                                        0.168824      0.375416
#
#                                        fl_terrace  fl_garden  \
# property_type                           -0.217590   0.301024
# zip_code                                -0.127446  -0.077550
# total_area_sqm                          -0.022017   0.033824
# nbr_bedrooms                            -0.024772   0.155898
# fl_terrace                               1.000000   0.109648
# fl_garden                                0.109648   1.000000
# primary_energy_consumption_sqm          -0.004006  -0.003189
# subproperty_type_APARTMENT               0.188362  -0.282552
# subproperty_type_APARTMENT_BLOCK        -0.061649   0.008975
# subproperty_type_BUNGALOW                0.007762   0.038304
# subproperty_type_CASTLE                 -0.009276  -0.006082
# subproperty_type_CHALET                  0.006810   0.010643
# subproperty_type_COUNTRY_COTTAGE        -0.008554   0.023885
# subproperty_type_DUPLEX                  0.028060  -0.036699
# subproperty_type_EXCEPTIONAL_PROPERTY    0.020571   0.039077
# subproperty_type_FARMHOUSE              -0.027989   0.010155
# subproperty_type_FLAT_STUDIO            -0.046192  -0.057778
# subproperty_type_GROUND_FLOOR            0.051153   0.079751
# subproperty_type_HOUSE                  -0.197698   0.233615
# subproperty_type_KOT                    -0.064206  -0.028328
# subproperty_type_LOFT                    0.013280  -0.021433
# subproperty_type_MANOR_HOUSE            -0.024788   0.010679
# subproperty_type_MANSION                 0.012647   0.059787
# subproperty_type_MIXED_USE_BUILDING     -0.034212  -0.006231
# subproperty_type_OTHER_PROPERTY         -0.010648   0.003513
# subproperty_type_PENTHOUSE               0.085035  -0.064148
# subproperty_type_SERVICE_FLAT            0.017595  -0.027268
# subproperty_type_TOWN_HOUSE              0.004820   0.055749
# subproperty_type_TRIPLEX                 0.005331   0.000737
# subproperty_type_VILLA                   0.013317   0.088276
# province_Antwerp                         0.038526   0.027096
# province_Brussels                        0.064546  -0.039461
# province_East Flanders                  -0.048604  -0.031630
# province_Flemish Brabant                 0.023846   0.017674
# province_Hainaut                        -0.034056   0.034856
# province_Limburg                        -0.031151  -0.007404
# province_Liège                           0.051844   0.066489
# province_Luxembourg                      0.007751   0.028785
# province_Namur                           0.017387   0.039971
# province_Walloon Brabant                 0.043325   0.075768
# province_West Flanders                  -0.094623  -0.132577
# state_building_AS_NEW                    0.184818   0.002435
# state_building_GOOD                     -0.036168   0.016124
# state_building_JUST_RENOVATED            0.021449   0.041357
# state_building_MISSING                  -0.067566  -0.105328
# state_building_TO_BE_DONE_UP            -0.020599   0.061857
# state_building_TO_RENOVATE              -0.085790   0.075258
# state_building_TO_RESTORE               -0.025086   0.016734
# price                                    0.031458   0.030347
#
#                                        primary_energy_consumption_sqm  \
# property_type                                                0.007671
# zip_code                                                     0.004020
# total_area_sqm                                               0.000709
# nbr_bedrooms                                                 0.003776
# fl_terrace                                                  -0.004006
# fl_garden                                                   -0.003189
# primary_energy_consumption_sqm                               1.000000
# subproperty_type_APARTMENT                                  -0.006280
# subproperty_type_APARTMENT_BLOCK                            -0.001053
# subproperty_type_BUNGALOW                                   -0.000324
# subproperty_type_CASTLE                                     -0.000166
# subproperty_type_CHALET                                     -0.000202
# subproperty_type_COUNTRY_COTTAGE                            -0.000071
# subproperty_type_DUPLEX                                     -0.001084
# subproperty_type_EXCEPTIONAL_PROPERTY                       -0.000648
# subproperty_type_FARMHOUSE                                   0.000245
# subproperty_type_FLAT_STUDIO                                -0.000955
# subproperty_type_GROUND_FLOOR                               -0.001347
# subproperty_type_HOUSE                                       0.004522
# subproperty_type_KOT                                        -0.000522
# subproperty_type_LOFT                                       -0.000487
# subproperty_type_MANOR_HOUSE                                -0.000305
# subproperty_type_MANSION                                    -0.000528
# subproperty_type_MIXED_USE_BUILDING                         -0.000965
# subproperty_type_OTHER_PROPERTY                             -0.000236
# subproperty_type_PENTHOUSE                                  -0.001205
# subproperty_type_SERVICE_FLAT                               -0.000661
# subproperty_type_TOWN_HOUSE                                 -0.000034
# subproperty_type_TRIPLEX                                    -0.000306
# subproperty_type_VILLA                                       0.010143
# province_Antwerp                                            -0.003044
# province_Brussels                                           -0.002540
# province_East Flanders                                       0.003910
# province_Flemish Brabant                                     0.005851
# province_Hainaut                                            -0.001931
# province_Limburg                                            -0.001612
# province_Liège                                              -0.002088
# province_Luxembourg                                         -0.001268
# province_Namur                                              -0.001338
# province_Walloon Brabant                                    -0.001494
# province_West Flanders                                       0.003140
# state_building_AS_NEW                                       -0.003798
# state_building_GOOD                                         -0.004444
# state_building_JUST_RENOVATED                               -0.001402
# state_building_MISSING                                      -0.000637
# state_building_TO_BE_DONE_UP                                 0.018774
# state_building_TO_RENOVATE                                  -0.001171
# state_building_TO_RESTORE                                    0.000142
# price                                                       -0.001436
#
#                                        subproperty_type_APARTMENT  \
# property_type                                           -0.817388
# zip_code                                                -0.022677
# total_area_sqm                                          -0.112800
# nbr_bedrooms                                            -0.337078
# fl_terrace                                               0.188362
# fl_garden                                               -0.282552
# primary_energy_consumption_sqm                          -0.006280
# subproperty_type_APARTMENT                               1.000000
# subproperty_type_APARTMENT_BLOCK                        -0.131235
# subproperty_type_BUNGALOW                               -0.049988
# subproperty_type_CASTLE                                 -0.020414
# subproperty_type_CHALET                                 -0.025108
# subproperty_type_COUNTRY_COTTAGE                        -0.040995
# subproperty_type_DUPLEX                                 -0.109708
# subproperty_type_EXCEPTIONAL_PROPERTY                   -0.070107
# subproperty_type_FARMHOUSE                              -0.042344
# subproperty_type_FLAT_STUDIO                            -0.096283
# subproperty_type_GROUND_FLOOR                           -0.132417
# subproperty_type_HOUSE                                  -0.632141
# subproperty_type_KOT                                    -0.048639
# subproperty_type_LOFT                                   -0.047467
# subproperty_type_MANOR_HOUSE                            -0.034948
# subproperty_type_MANSION                                -0.060653
# subproperty_type_MIXED_USE_BUILDING                     -0.114197
# subproperty_type_OTHER_PROPERTY                         -0.026489
# subproperty_type_PENTHOUSE                              -0.114799
# subproperty_type_SERVICE_FLAT                           -0.060483
# subproperty_type_TOWN_HOUSE                             -0.061745
# subproperty_type_TRIPLEX                                -0.030759
# subproperty_type_VILLA                                  -0.167178
# province_Antwerp                                         0.024909
# province_Brussels                                        0.118165
# province_East Flanders                                  -0.051970
# province_Flemish Brabant                                -0.075947
# province_Hainaut                                        -0.090512
# province_Limburg                                        -0.012371
# province_Liège                                          -0.035072
# province_Luxembourg                                     -0.024745
# province_Namur                                          -0.014047
# province_Walloon Brabant                                -0.030650
# province_West Flanders                                   0.136514
# state_building_AS_NEW                                    0.076245
# state_building_GOOD                                     -0.034513
# state_building_JUST_RENOVATED                           -0.016242
# state_building_MISSING                                   0.105511
# state_building_TO_BE_DONE_UP                            -0.081800
# state_building_TO_RENOVATE                              -0.159247
# state_building_TO_RESTORE                               -0.036712
# price                                                   -0.106994
#
#                                        subproperty_type_APARTMENT_BLOCK  \
# property_type                                                  0.160554
# zip_code                                                      -0.053415
# total_area_sqm                                                 0.063752
# nbr_bedrooms                                                   0.193912
# fl_terrace                                                    -0.061649
# fl_garden                                                      0.008975
# primary_energy_consumption_sqm                                -0.001053
# subproperty_type_APARTMENT                                    -0.131235
# subproperty_type_APARTMENT_BLOCK                               1.000000
# subproperty_type_BUNGALOW                                     -0.010747
# subproperty_type_CASTLE                                       -0.004389
# subproperty_type_CHALET                                       -0.005398
# subproperty_type_COUNTRY_COTTAGE                              -0.008813
# subproperty_type_DUPLEX                                       -0.023585
# subproperty_type_EXCEPTIONAL_PROPERTY                         -0.015072
# subproperty_type_FARMHOUSE                                    -0.009103
# subproperty_type_FLAT_STUDIO                                  -0.020699
# subproperty_type_GROUND_FLOOR                                 -0.028467
# subproperty_type_HOUSE                                        -0.135899
# subproperty_type_KOT                                          -0.010456
# subproperty_type_LOFT                                         -0.010205
# subproperty_type_MANOR_HOUSE                                  -0.007513
# subproperty_type_MANSION                                      -0.013039
# subproperty_type_MIXED_USE_BUILDING                           -0.024550
# subproperty_type_OTHER_PROPERTY                               -0.005695
# subproperty_type_PENTHOUSE                                    -0.024680
# subproperty_type_SERVICE_FLAT                                 -0.013003
# subproperty_type_TOWN_HOUSE                                   -0.013274
# subproperty_type_TRIPLEX                                      -0.006613
# subproperty_type_VILLA                                        -0.035940
# province_Antwerp                                              -0.000367
# province_Brussels                                              0.058027
# province_East Flanders                                        -0.037624
# province_Flemish Brabant                                      -0.024667
# province_Hainaut                                               0.045411
# province_Limburg                                              -0.023518
# province_Liège                                                 0.052971
# province_Luxembourg                                           -0.004812
# province_Namur                                                 0.009732
# province_Walloon Brabant                                      -0.013543
# province_West Flanders                                        -0.058062
# state_building_AS_NEW                                         -0.048154
# state_building_GOOD                                            0.016891
# state_building_JUST_RENOVATED                                  0.007231
# state_building_MISSING                                        -0.018159
# state_building_TO_BE_DONE_UP                                   0.038906
# state_building_TO_RENOVATE                                     0.030965
# state_building_TO_RESTORE                                      0.027852
# price                                                          0.090240
#
#                                        subproperty_type_BUNGALOW  \
# property_type                                           0.061156
# zip_code                                                0.006208
# total_area_sqm                                         -0.003866
# nbr_bedrooms                                           -0.007517
# fl_terrace                                              0.007762
# fl_garden                                               0.038304
# primary_energy_consumption_sqm                         -0.000324
# subproperty_type_APARTMENT                             -0.049988
# subproperty_type_APARTMENT_BLOCK                       -0.010747
# subproperty_type_BUNGALOW                               1.000000
# subproperty_type_CASTLE                                -0.001672
# subproperty_type_CHALET                                -0.002056
# subproperty_type_COUNTRY_COTTAGE                       -0.003357
# subproperty_type_DUPLEX                                -0.008984
# subproperty_type_EXCEPTIONAL_PROPERTY                  -0.005741
# subproperty_type_FARMHOUSE                             -0.003467
# subproperty_type_FLAT_STUDIO                           -0.007884
# subproperty_type_GROUND_FLOOR                          -0.010843
# subproperty_type_HOUSE                                 -0.051765
# subproperty_type_KOT                                   -0.003983
# subproperty_type_LOFT                                  -0.003887
# subproperty_type_MANOR_HOUSE                           -0.002862
# subproperty_type_MANSION                               -0.004967
# subproperty_type_MIXED_USE_BUILDING                    -0.009351
# subproperty_type_OTHER_PROPERTY                        -0.002169
# subproperty_type_PENTHOUSE                             -0.009401
# subproperty_type_SERVICE_FLAT                          -0.004953
# subproperty_type_TOWN_HOUSE                            -0.005056
# subproperty_type_TRIPLEX                               -0.002519
# subproperty_type_VILLA                                 -0.013690
# province_Antwerp                                       -0.017886
# province_Brussels                                      -0.021124
# province_East Flanders                                  0.011356
# province_Flemish Brabant                                0.016846
# province_Hainaut                                       -0.015834
# province_Limburg                                        0.003548
# province_Liège                                          0.040201
# province_Luxembourg                                    -0.001744
# province_Namur                                          0.005741
# province_Walloon Brabant                               -0.002640
# province_West Flanders                                 -0.010313
# state_building_AS_NEW                                  -0.011688
# state_building_GOOD                                     0.007261
# state_building_JUST_RENOVATED                          -0.003031
# state_building_MISSING                                 -0.015573
# state_building_TO_BE_DONE_UP                            0.015731
# state_building_TO_RENOVATE                              0.023386
# state_building_TO_RESTORE                              -0.004338
# price                                                  -0.013428
#
#                                        subproperty_type_CASTLE  \
# property_type                                         0.024975
# zip_code                                             -0.000866
# total_area_sqm                                        0.074969
# nbr_bedrooms                                          0.134121
# fl_terrace                                           -0.009276
# fl_garden                                            -0.006082
# primary_energy_consumption_sqm                       -0.000166
# subproperty_type_APARTMENT                           -0.020414
# subproperty_type_APARTMENT_BLOCK                     -0.004389
# subproperty_type_BUNGALOW                            -0.001672
# subproperty_type_CASTLE                               1.000000
# subproperty_type_CHALET                              -0.000840
# subproperty_type_COUNTRY_COTTAGE                     -0.001371
# subproperty_type_DUPLEX                              -0.003669
# subproperty_type_EXCEPTIONAL_PROPERTY                -0.002344
# subproperty_type_FARMHOUSE                           -0.001416
# subproperty_type_FLAT_STUDIO                         -0.003220
# subproperty_type_GROUND_FLOOR                        -0.004428
# subproperty_type_HOUSE                               -0.021140
# subproperty_type_KOT                                 -0.001627
# subproperty_type_LOFT                                -0.001587
# subproperty_type_MANOR_HOUSE                         -0.001169
# subproperty_type_MANSION                             -0.002028
# subproperty_type_MIXED_USE_BUILDING                  -0.003819
# subproperty_type_OTHER_PROPERTY                      -0.000886
# subproperty_type_PENTHOUSE                           -0.003839
# subproperty_type_SERVICE_FLAT                        -0.002023
# subproperty_type_TOWN_HOUSE                          -0.002065
# subproperty_type_TRIPLEX                             -0.001029
# subproperty_type_VILLA                               -0.005591
# province_Antwerp                                     -0.005192
# province_Brussels                                    -0.006899
# province_East Flanders                               -0.004951
# province_Flemish Brabant                              0.000554
# province_Hainaut                                      0.006458
# province_Limburg                                      0.000401
# province_Liège                                        0.009041
# province_Luxembourg                                   0.006859
# province_Namur                                        0.020823
# province_Walloon Brabant                             -0.002169
# province_West Flanders                               -0.011256
# state_building_AS_NEW                                -0.006415
# state_building_GOOD                                   0.000304
# state_building_JUST_RENOVATED                        -0.001253
# state_building_MISSING                               -0.000634
# state_building_TO_BE_DONE_UP                         -0.000946
# state_building_TO_RENOVATE                            0.010315
# state_building_TO_RESTORE                             0.007671
# price                                                 0.075831
#
#                                        subproperty_type_CHALET  \
# property_type                                         0.030718
# zip_code                                              0.003716
# total_area_sqm                                       -0.004720
# nbr_bedrooms                                         -0.008503
# fl_terrace                                            0.006810
# fl_garden                                             0.010643
# primary_energy_consumption_sqm                       -0.000202
# subproperty_type_APARTMENT                           -0.025108
# subproperty_type_APARTMENT_BLOCK                     -0.005398
# subproperty_type_BUNGALOW                            -0.002056
# subproperty_type_CASTLE                              -0.000840
# subproperty_type_CHALET                               1.000000
# subproperty_type_COUNTRY_COTTAGE                     -0.001686
# subproperty_type_DUPLEX                              -0.004512
# subproperty_type_EXCEPTIONAL_PROPERTY                -0.002884
# subproperty_type_FARMHOUSE                           -0.001742
# subproperty_type_FLAT_STUDIO                         -0.003960
# subproperty_type_GROUND_FLOOR                        -0.005446
# subproperty_type_HOUSE                               -0.026001
# subproperty_type_KOT                                 -0.002001
# subproperty_type_LOFT                                -0.001952
# subproperty_type_MANOR_HOUSE                         -0.001437
# subproperty_type_MANSION                             -0.002495
# subproperty_type_MIXED_USE_BUILDING                  -0.004697
# subproperty_type_OTHER_PROPERTY                      -0.001090
# subproperty_type_PENTHOUSE                           -0.004722
# subproperty_type_SERVICE_FLAT                        -0.002488
# subproperty_type_TOWN_HOUSE                          -0.002540
# subproperty_type_TRIPLEX                             -0.001265
# subproperty_type_VILLA                               -0.006876
# province_Antwerp                                      0.000229
# province_Brussels                                    -0.011037
# province_East Flanders                               -0.011394
# province_Flemish Brabant                             -0.008398
# province_Hainaut                                     -0.010021
# province_Limburg                                     -0.004537
# province_Liège                                        0.003845
# province_Luxembourg                                   0.059229
# province_Namur                                        0.038635
# province_Walloon Brabant                             -0.004010
# province_West Flanders                               -0.010991
# state_building_AS_NEW                                -0.002719
# state_building_GOOD                                   0.005933
# state_building_JUST_RENOVATED                        -0.003028
# state_building_MISSING                                0.000119
# state_building_TO_BE_DONE_UP                          0.003246
# state_building_TO_RENOVATE                           -0.006785
# state_building_TO_RESTORE                            -0.002179
# price                                                -0.018378
#
#                                        subproperty_type_COUNTRY_COTTAGE  \
# property_type                                                  0.050154
# zip_code                                                       0.006293
# total_area_sqm                                                 0.034456
# nbr_bedrooms                                                   0.030511
# fl_terrace                                                    -0.008554
# fl_garden                                                      0.023885
# primary_energy_consumption_sqm                                -0.000071
# subproperty_type_APARTMENT                                    -0.040995
# subproperty_type_APARTMENT_BLOCK                              -0.008813
# subproperty_type_BUNGALOW                                     -0.003357
# subproperty_type_CASTLE                                       -0.001371
# subproperty_type_CHALET                                       -0.001686
# subproperty_type_COUNTRY_COTTAGE                               1.000000
# subproperty_type_DUPLEX                                       -0.007368
# subproperty_type_EXCEPTIONAL_PROPERTY                         -0.004708
# subproperty_type_FARMHOUSE                                    -0.002844
# subproperty_type_FLAT_STUDIO                                  -0.006466
# subproperty_type_GROUND_FLOOR                                 -0.008893
# subproperty_type_HOUSE                                        -0.042452
# subproperty_type_KOT                                          -0.003266
# subproperty_type_LOFT                                         -0.003188
# subproperty_type_MANOR_HOUSE                                  -0.002347
# subproperty_type_MANSION                                      -0.004073
# subproperty_type_MIXED_USE_BUILDING                           -0.007669
# subproperty_type_OTHER_PROPERTY                               -0.001779
# subproperty_type_PENTHOUSE                                    -0.007709
# subproperty_type_SERVICE_FLAT                                 -0.004062
# subproperty_type_TOWN_HOUSE                                   -0.004147
# subproperty_type_TRIPLEX                                      -0.002066
# subproperty_type_VILLA                                        -0.011227
# province_Antwerp                                              -0.005947
# province_Brussels                                             -0.018021
# province_East Flanders                                        -0.001729
# province_Flemish Brabant                                       0.001004
# province_Hainaut                                               0.016748
# province_Limburg                                              -0.005367
# province_Liège                                                 0.004873
# province_Luxembourg                                            0.013635
# province_Namur                                                 0.018679
# province_Walloon Brabant                                       0.008462
# province_West Flanders                                        -0.014727
# state_building_AS_NEW                                         -0.008947
# state_building_GOOD                                           -0.008730
# state_building_JUST_RENOVATED                                  0.001004
# state_building_MISSING                                        -0.013478
# state_building_TO_BE_DONE_UP                                   0.018575
# state_building_TO_RENOVATE                                     0.036703
# state_building_TO_RESTORE                                      0.001154
# price                                                          0.010929
#
#                                        subproperty_type_DUPLEX  \
# property_type                                        -0.146900
# zip_code                                             -0.042988
# total_area_sqm                                       -0.012412
# nbr_bedrooms                                         -0.023663
# fl_terrace                                            0.028060
# fl_garden                                            -0.036699
# primary_energy_consumption_sqm                       -0.001084
# subproperty_type_APARTMENT                           -0.109708
# subproperty_type_APARTMENT_BLOCK                     -0.023585
# subproperty_type_BUNGALOW                            -0.008984
# subproperty_type_CASTLE                              -0.003669
# subproperty_type_CHALET                              -0.004512
# subproperty_type_COUNTRY_COTTAGE                     -0.007368
# subproperty_type_DUPLEX                               1.000000
# subproperty_type_EXCEPTIONAL_PROPERTY                -0.012599
# subproperty_type_FARMHOUSE                           -0.007610
# subproperty_type_FLAT_STUDIO                         -0.017304
# subproperty_type_GROUND_FLOOR                        -0.023798
# subproperty_type_HOUSE                               -0.113607
# subproperty_type_KOT                                 -0.008741
# subproperty_type_LOFT                                -0.008531
# subproperty_type_MANOR_HOUSE                         -0.006281
# subproperty_type_MANSION                             -0.010900
# subproperty_type_MIXED_USE_BUILDING                  -0.020523
# subproperty_type_OTHER_PROPERTY                      -0.004761
# subproperty_type_PENTHOUSE                           -0.020631
# subproperty_type_SERVICE_FLAT                        -0.010870
# subproperty_type_TOWN_HOUSE                          -0.011097
# subproperty_type_TRIPLEX                             -0.005528
# subproperty_type_VILLA                               -0.030045
# province_Antwerp                                      0.003876
# province_Brussels                                     0.041456
# province_East Flanders                               -0.014379
# province_Flemish Brabant                              0.031329
# province_Hainaut                                     -0.028594
# province_Limburg                                     -0.006350
# province_Liège                                       -0.015455
# province_Luxembourg                                  -0.014946
# province_Namur                                       -0.013661
# province_Walloon Brabant                              0.009509
# province_West Flanders                                0.000370
# state_building_AS_NEW                                 0.040776
# state_building_GOOD                                   0.001073
# state_building_JUST_RENOVATED                         0.012670
# state_building_MISSING                               -0.015995
# state_building_TO_BE_DONE_UP                         -0.017410
# state_building_TO_RENOVATE                           -0.026684
# state_building_TO_RESTORE                            -0.005939
# price                                                 0.013047
#
#                                        subproperty_type_EXCEPTIONAL_PROPERTY  \
# property_type                                                       0.085769
# zip_code                                                           -0.020634
# total_area_sqm                                                      0.052646
# nbr_bedrooms                                                        0.116467
# fl_terrace                                                          0.020571
# fl_garden                                                           0.039077
# primary_energy_consumption_sqm                                     -0.000648
# subproperty_type_APARTMENT                                         -0.070107
# subproperty_type_APARTMENT_BLOCK                                   -0.015072
# subproperty_type_BUNGALOW                                          -0.005741
# subproperty_type_CASTLE                                            -0.002344
# subproperty_type_CHALET                                            -0.002884
# subproperty_type_COUNTRY_COTTAGE                                   -0.004708
# subproperty_type_DUPLEX                                            -0.012599
# subproperty_type_EXCEPTIONAL_PROPERTY                               1.000000
# subproperty_type_FARMHOUSE                                         -0.004863
# subproperty_type_FLAT_STUDIO                                       -0.011058
# subproperty_type_GROUND_FLOOR                                      -0.015207
# subproperty_type_HOUSE                                             -0.072598
# subproperty_type_KOT                                               -0.005586
# subproperty_type_LOFT                                              -0.005451
# subproperty_type_MANOR_HOUSE                                       -0.004014
# subproperty_type_MANSION                                           -0.006966
# subproperty_type_MIXED_USE_BUILDING                                -0.013115
# subproperty_type_OTHER_PROPERTY                                    -0.003042
# subproperty_type_PENTHOUSE                                         -0.013184
# subproperty_type_SERVICE_FLAT                                      -0.006946
# subproperty_type_TOWN_HOUSE                                        -0.007091
# subproperty_type_TRIPLEX                                           -0.003533
# subproperty_type_VILLA                                             -0.019200
# province_Antwerp                                                   -0.001861
# province_Brussels                                                  -0.000393
# province_East Flanders                                             -0.015447
# province_Flemish Brabant                                            0.009795
# province_Hainaut                                                    0.008950
# province_Limburg                                                   -0.001682
# province_Liège                                                     -0.000107
# province_Luxembourg                                                 0.011179
# province_Namur                                                      0.015306
# province_Walloon Brabant                                            0.019280
# province_West Flanders                                             -0.021677
# state_building_AS_NEW                                               0.036578
# state_building_GOOD                                                -0.004941
# state_building_JUST_RENOVATED                                       0.009620
# state_building_MISSING                                             -0.031084
# state_building_TO_BE_DONE_UP                                       -0.004389
# state_building_TO_RENOVATE                                          0.005420
# state_building_TO_RESTORE                                           0.007765
# price                                                               0.154519
#
#                                        subproperty_type_FARMHOUSE  \
# property_type                                            0.051804
# zip_code                                                 0.008143
# total_area_sqm                                           0.022845
# nbr_bedrooms                                             0.038097
# fl_terrace                                              -0.027989
# fl_garden                                                0.010155
# primary_energy_consumption_sqm                           0.000245
# subproperty_type_APARTMENT                              -0.042344
# subproperty_type_APARTMENT_BLOCK                        -0.009103
# subproperty_type_BUNGALOW                               -0.003467
# subproperty_type_CASTLE                                 -0.001416
# subproperty_type_CHALET                                 -0.001742
# subproperty_type_COUNTRY_COTTAGE                        -0.002844
# subproperty_type_DUPLEX                                 -0.007610
# subproperty_type_EXCEPTIONAL_PROPERTY                   -0.004863
# subproperty_type_FARMHOUSE                               1.000000
# subproperty_type_FLAT_STUDIO                            -0.006679
# subproperty_type_GROUND_FLOOR                           -0.009185
# subproperty_type_HOUSE                                  -0.043849
# subproperty_type_KOT                                    -0.003374
# subproperty_type_LOFT                                   -0.003293
# subproperty_type_MANOR_HOUSE                            -0.002424
# subproperty_type_MANSION                                -0.004207
# subproperty_type_MIXED_USE_BUILDING                     -0.007921
# subproperty_type_OTHER_PROPERTY                         -0.001837
# subproperty_type_PENTHOUSE                              -0.007963
# subproperty_type_SERVICE_FLAT                           -0.004195
# subproperty_type_TOWN_HOUSE                             -0.004283
# subproperty_type_TRIPLEX                                -0.002134
# subproperty_type_VILLA                                  -0.011596
# province_Antwerp                                        -0.007140
# province_Brussels                                       -0.018614
# province_East Flanders                                  -0.013725
# province_Flemish Brabant                                -0.001170
# province_Hainaut                                         0.021722
# province_Limburg                                         0.008827
# province_Liège                                           0.016283
# province_Luxembourg                                      0.018116
# province_Namur                                           0.000038
# province_Walloon Brabant                                -0.001842
# province_West Flanders                                  -0.008093
# state_building_AS_NEW                                   -0.018104
# state_building_GOOD                                     -0.001759
# state_building_JUST_RENOVATED                           -0.008278
# state_building_MISSING                                  -0.008466
# state_building_TO_BE_DONE_UP                            -0.008044
# state_building_TO_RENOVATE                               0.044267
# state_building_TO_RESTORE                                0.060202
# price                                                    0.031008
#
#                                        subproperty_type_FLAT_STUDIO  \
# property_type                                             -0.128923
# zip_code                                                  -0.052040
# total_area_sqm                                            -0.034393
# nbr_bedrooms                                              -0.169394
# fl_terrace                                                -0.046192
# fl_garden                                                 -0.057778
# primary_energy_consumption_sqm                            -0.000955
# subproperty_type_APARTMENT                                -0.096283
# subproperty_type_APARTMENT_BLOCK                          -0.020699
# subproperty_type_BUNGALOW                                 -0.007884
# subproperty_type_CASTLE                                   -0.003220
# subproperty_type_CHALET                                   -0.003960
# subproperty_type_COUNTRY_COTTAGE                          -0.006466
# subproperty_type_DUPLEX                                   -0.017304
# subproperty_type_EXCEPTIONAL_PROPERTY                     -0.011058
# subproperty_type_FARMHOUSE                                -0.006679
# subproperty_type_FLAT_STUDIO                               1.000000
# subproperty_type_GROUND_FLOOR                             -0.020886
# subproperty_type_HOUSE                                    -0.099705
# subproperty_type_KOT                                      -0.007672
# subproperty_type_LOFT                                     -0.007487
# subproperty_type_MANOR_HOUSE                              -0.005512
# subproperty_type_MANSION                                  -0.009567
# subproperty_type_MIXED_USE_BUILDING                       -0.018012
# subproperty_type_OTHER_PROPERTY                           -0.004178
# subproperty_type_PENTHOUSE                                -0.018107
# subproperty_type_SERVICE_FLAT                             -0.009540
# subproperty_type_TOWN_HOUSE                               -0.009739
# subproperty_type_TRIPLEX                                  -0.004852
# subproperty_type_VILLA                                    -0.026368
# province_Antwerp                                          -0.012252
# province_Brussels                                          0.105367
# province_East Flanders                                    -0.039924
# province_Flemish Brabant                                   0.007031
# province_Hainaut                                          -0.034362
# ...
# subproperty_type_MIXED_USE_BUILDING                        -0.000921
# subproperty_type_OTHER_PROPERTY                            -0.000752
# subproperty_type_PENTHOUSE                                 -0.001842
# subproperty_type_SERVICE_FLAT                              -0.008232
# subproperty_type_TOWN_HOUSE                                 0.005592
# subproperty_type_TRIPLEX                                    0.014078
# subproperty_type_VILLA                                     -0.009879
# province_Antwerp                                            0.031590
# province_Brussels                                           0.021874
# province_East Flanders                                     -0.031438
# province_Flemish Brabant                                   -0.008433
# province_Hainaut                                            0.021940
# province_Limburg                                           -0.019327
# province_Liège                                             -0.005847
# province_Luxembourg                                        -0.008078
# province_Namur                                              0.007894
# province_Walloon Brabant                                    0.000557
# province_West Flanders                                     -0.016658
# state_building_AS_NEW                                      -0.090787
# state_building_GOOD                                        -0.117225
# state_building_JUST_RENOVATED                               1.000000
# state_building_MISSING                                     -0.136356
# state_building_TO_BE_DONE_UP                               -0.045460
# state_building_TO_RENOVATE                                 -0.050641
# state_building_TO_RESTORE                                  -0.012515
# price                                                       0.010804
#
#                                        state_building_MISSING  \
# property_type                                       -0.093793
# zip_code                                             0.041130
# total_area_sqm                                      -0.024777
# nbr_bedrooms                                        -0.063207
# fl_terrace                                          -0.067566
# fl_garden                                           -0.105328
# primary_energy_consumption_sqm                      -0.000637
# subproperty_type_APARTMENT                           0.105511
# subproperty_type_APARTMENT_BLOCK                    -0.018159
# subproperty_type_BUNGALOW                           -0.015573
# subproperty_type_CASTLE                             -0.000634
# subproperty_type_CHALET                              0.000119
# subproperty_type_COUNTRY_COTTAGE                    -0.013478
# subproperty_type_DUPLEX                             -0.015995
# subproperty_type_EXCEPTIONAL_PROPERTY               -0.031084
# subproperty_type_FARMHOUSE                          -0.008466
# subproperty_type_FLAT_STUDIO                        -0.009007
# subproperty_type_GROUND_FLOOR                        0.003289
# subproperty_type_HOUSE                              -0.045813
# subproperty_type_KOT                                -0.010617
# subproperty_type_LOFT                               -0.013820
# subproperty_type_MANOR_HOUSE                        -0.004186
# subproperty_type_MANSION                            -0.040203
# subproperty_type_MIXED_USE_BUILDING                 -0.029147
# subproperty_type_OTHER_PROPERTY                     -0.002428
# subproperty_type_PENTHOUSE                           0.002811
# subproperty_type_SERVICE_FLAT                        0.000726
# subproperty_type_TOWN_HOUSE                         -0.027349
# subproperty_type_TRIPLEX                            -0.014026
# subproperty_type_VILLA                              -0.033507
# province_Antwerp                                     0.001975
# province_Brussels                                   -0.068653
# province_East Flanders                               0.007247
# province_Flemish Brabant                            -0.016358
# province_Hainaut                                     0.011978
# province_Limburg                                     0.053246
# province_Liège                                       0.011380
# province_Luxembourg                                  0.006673
# province_Namur                                       0.008388
# province_Walloon Brabant                            -0.008281
# province_West Flanders                               0.008886
# state_building_AS_NEW                               -0.363362
# state_building_GOOD                                 -0.469175
# state_building_JUST_RENOVATED                       -0.136356
# state_building_MISSING                               1.000000
# state_building_TO_BE_DONE_UP                        -0.181948
# state_building_TO_RENOVATE                          -0.202681
# state_building_TO_RESTORE                           -0.050088
# price                                               -0.056180
#
#                                        state_building_TO_BE_DONE_UP  \
# property_type                                              0.103865
# zip_code                                                  -0.035334
# total_area_sqm                                             0.006932
# nbr_bedrooms                                               0.046885
# fl_terrace                                                -0.020599
# fl_garden                                                  0.061857
# primary_energy_consumption_sqm                             0.018774
# subproperty_type_APARTMENT                                -0.081800
# subproperty_type_APARTMENT_BLOCK                           0.038906
# subproperty_type_BUNGALOW                                  0.015731
# subproperty_type_CASTLE                                   -0.000946
# subproperty_type_CHALET                                    0.003246
# subproperty_type_COUNTRY_COTTAGE                           0.018575
# subproperty_type_DUPLEX                                   -0.017410
# subproperty_type_EXCEPTIONAL_PROPERTY                     -0.004389
# subproperty_type_FARMHOUSE                                -0.008044
# subproperty_type_FLAT_STUDIO                               0.007429
# subproperty_type_GROUND_FLOOR                             -0.020429
# subproperty_type_HOUSE                                     0.076531
# subproperty_type_KOT                                      -0.013021
# subproperty_type_LOFT                                     -0.014963
# subproperty_type_MANOR_HOUSE                               0.003431
# subproperty_type_MANSION                                   0.021741
# subproperty_type_MIXED_USE_BUILDING                        0.029600
# subproperty_type_OTHER_PROPERTY                            0.008578
# subproperty_type_PENTHOUSE                                -0.030209
# subproperty_type_SERVICE_FLAT                             -0.017204
# subproperty_type_TOWN_HOUSE                                0.020683
# subproperty_type_TRIPLEX                                   0.001242
# subproperty_type_VILLA                                    -0.005418
# province_Antwerp                                          -0.011342
# province_Brussels                                          0.034138
# province_East Flanders                                    -0.011523
# province_Flemish Brabant                                  -0.008781
# province_Hainaut                                           0.014632
# province_Limburg                                          -0.009155
# province_Liège                                             0.039659
# province_Luxembourg                                        0.004303
# province_Namur                                            -0.001186
# province_Walloon Brabant                                   0.006052
# province_West Flanders                                    -0.044175
# state_building_AS_NEW                                     -0.121142
# state_building_GOOD                                       -0.156420
# state_building_JUST_RENOVATED                             -0.045460
# state_building_MISSING                                    -0.181948
# state_building_TO_BE_DONE_UP                               1.000000
# state_building_TO_RENOVATE                                -0.067573
# state_building_TO_RESTORE                                 -0.016699
# price                                                     -0.049386
#
#                                        state_building_TO_RENOVATE  \
# property_type                                            0.192529
# zip_code                                                -0.024081
# total_area_sqm                                           0.034981
# nbr_bedrooms                                             0.076548
# fl_terrace                                              -0.085790
# fl_garden                                                0.075258
# primary_energy_consumption_sqm                          -0.001171
# subproperty_type_APARTMENT                              -0.159247
# subproperty_type_APARTMENT_BLOCK                         0.030965
# subproperty_type_BUNGALOW                                0.023386
# subproperty_type_CASTLE                                  0.010315
# subproperty_type_CHALET                                 -0.006785
# subproperty_type_COUNTRY_COTTAGE                         0.036703
# subproperty_type_DUPLEX                                 -0.026684
# subproperty_type_EXCEPTIONAL_PROPERTY                    0.005420
# subproperty_type_FARMHOUSE                               0.044267
# subproperty_type_FLAT_STUDIO                            -0.015544
# subproperty_type_GROUND_FLOOR                           -0.030269
# subproperty_type_HOUSE                                   0.154920
# subproperty_type_KOT                                    -0.017080
# subproperty_type_LOFT                                   -0.010204
# subproperty_type_MANOR_HOUSE                             0.019867
# subproperty_type_MANSION                                 0.037861
# subproperty_type_MIXED_USE_BUILDING                      0.045574
# subproperty_type_OTHER_PROPERTY                          0.004178
# subproperty_type_PENTHOUSE                              -0.036684
# subproperty_type_SERVICE_FLAT                           -0.020391
# subproperty_type_TOWN_HOUSE                             -0.000092
# subproperty_type_TRIPLEX                                 0.004131
# subproperty_type_VILLA                                  -0.007069
# province_Antwerp                                         0.010776
# province_Brussels                                        0.006179
# province_East Flanders                                   0.004276
# province_Flemish Brabant                                 0.005263
# province_Hainaut                                         0.013865
# province_Limburg                                        -0.007423
# province_Liège                                           0.001146
# province_Luxembourg                                      0.004543
# province_Namur                                           0.005432
# province_Walloon Brabant                                 0.015583
# province_West Flanders                                  -0.046220
# state_building_AS_NEW                                   -0.134947
# state_building_GOOD                                     -0.174245
# state_building_JUST_RENOVATED                           -0.050641
# state_building_MISSING                                  -0.202681
# state_building_TO_BE_DONE_UP                            -0.067573
# state_building_TO_RENOVATE                               1.000000
# state_building_TO_RESTORE                               -0.018602
# price                                                   -0.048923
#
#                                        state_building_TO_RESTORE     price
# property_type                                           0.045558  0.113362
# zip_code                                                0.006258 -0.035565
# total_area_sqm                                          0.011246  0.168824
# nbr_bedrooms                                            0.026970  0.375416
# fl_terrace                                             -0.025086  0.031458
# fl_garden                                               0.016734  0.030347
# primary_energy_consumption_sqm                          0.000142 -0.001436
# subproperty_type_APARTMENT                             -0.036712 -0.106994
# subproperty_type_APARTMENT_BLOCK                        0.027852  0.090240
# subproperty_type_BUNGALOW                              -0.004338 -0.013428
# subproperty_type_CASTLE                                 0.007671  0.075831
# subproperty_type_CHALET                                -0.002179 -0.018378
# subproperty_type_COUNTRY_COTTAGE                        0.001154  0.010929
# subproperty_type_DUPLEX                                -0.005939  0.013047
# subproperty_type_EXCEPTIONAL_PROPERTY                   0.007765  0.154519
# subproperty_type_FARMHOUSE                              0.060202  0.031008
# subproperty_type_FLAT_STUDIO                           -0.008355 -0.063320
# subproperty_type_GROUND_FLOOR                          -0.008498 -0.034295
# subproperty_type_HOUSE                                  0.028842 -0.060029
# subproperty_type_KOT                                   -0.004221 -0.027609
# subproperty_type_LOFT                                   0.004027  0.005992
# subproperty_type_MANOR_HOUSE                           -0.003033  0.056488
# subproperty_type_MANSION                                0.001127  0.068272
# subproperty_type_MIXED_USE_BUILDING                     0.002150  0.036125
# subproperty_type_OTHER_PROPERTY                         0.026823  0.002871
# subproperty_type_PENTHOUSE                             -0.008248  0.070866
# subproperty_type_SERVICE_FLAT                          -0.005249 -0.027592
# subproperty_type_TOWN_HOUSE                             0.004060 -0.007765
# subproperty_type_TRIPLEX                               -0.002669  0.002673
# subproperty_type_VILLA                                 -0.006072  0.206509
# province_Antwerp                                       -0.017789 -0.002387
# province_Brussels                                       0.000790  0.094536
# province_East Flanders                                 -0.010795 -0.008877
# province_Flemish Brabant                               -0.006115  0.032253
# province_Hainaut                                        0.027801 -0.120347
# province_Limburg                                       -0.012452 -0.025636
# province_Liège                                          0.011926 -0.082649
# province_Luxembourg                                     0.010281 -0.030826
# province_Namur                                          0.016555 -0.050300
# province_Walloon Brabant                                0.000966  0.034657
# province_West Flanders                                 -0.009531  0.114792
# state_building_AS_NEW                                  -0.033349  0.107539
# state_building_GOOD                                    -0.043060  0.016322
# state_building_JUST_RENOVATED                          -0.012515  0.010804
# state_building_MISSING                                 -0.050088 -0.056180
# state_building_TO_BE_DONE_UP                           -0.016699 -0.049386
# state_building_TO_RENOVATE                             -0.018602 -0.048923
# state_building_TO_RESTORE                               1.000000 -0.016385
# price                                                  -0.016385  1.000000

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

regressor.fit(X_train, y_train)

train_score = regressor.score(X_train, y_train)
print(f'Training score: {train_score}')

test_score = regressor.score(X_test, y_test)
print(f'Training score: {test_score}')
# Out:
# Training score: 0.28347174043656176
# Training score: 0.21795169915354717
